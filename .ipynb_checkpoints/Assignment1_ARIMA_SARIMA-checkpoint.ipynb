# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA

# %% [markdown]
# ### Data processing

# %%
#LOAD The data
path = 'dataset_mood_smartphone.csv'
df = pd.read_csv(path, header=0, sep=',', index_col=0)

#Split time column into time and date
date, time = df['time'].str.split(' ', 1).str
df.drop(labels=['time'], axis=1,inplace = True)
df.insert(1, 'date', date)
df.insert(2, 'time', time)

#sort on id and date
df = df.sort_values(by=['id', 'date'])

#Get the unique id's and data variables
ids = df.id.unique()
inputs = df.variable.unique()
uniquedays = df.date.unique()

# %%
#function to merge the days of the variables per patient  ##Note takes a while to complete
def mergedays(df):
    table = pd.DataFrame(columns=['id','date', 'variable', 'value'])
    ids = df.id.unique()
    #Rebuild the dataframe for every patient, day , variable
    i = 0
    for patientid in ids:
        patientdata = df.loc[df['id'] == patientid]
        days = patientdata.date.unique()
        for day in days:
            daydata = patientdata.loc[patientdata['date'] == day]
            variables = daydata.variable.unique()
            for var in variables:
                if var == 'mood' or var == 'circumplex.arousal' or var == 'circumplex.valence':
                    value = daydata.loc[daydata['variable'] == var].mean()[0]
                else:
                    #note due to sum suming over all indexing is needed
                    value = daydata.loc[daydata['variable'] == var].sum()[4]

                #print([patientid,day,var,value])
                table.loc[i] = [patientid,day,var,value]
                i+=1
    return table

# %%
#STATUS PRINTS      #NOTE before cleaning
print("STATISTICS")
print("The amount of unique ids are: ", len(ids), "\n", ids)
print("Amount of unique days are: ", len(uniquedays), "\n", uniquedays)
print("\nThe variables used are:\n", inputs)

print("\nErrors are within:  circumplex.valence 156 NA & circumplex.arousal 46 NA")
print("The count and amount of data inputs do not match")

print("\nHow many data points per id:")
datalist = []
for i in ids:
    datalist.append(len(df.loc[df['id'] == i]))
    print(i, " amount of data inputs: ", len(df.loc[df['id'] == i]))

vardatalist = []
print("\nHow often are the variables used:")
for j in inputs:
    vardatalist.append(len(df.loc[df['variable'] == j]))
    print(j, "\nAmount of data inputs: ", len(df.loc[df['variable'] == j]))
    print(df.loc[df['variable'] == j].describe(),"\n")
# Out:
# STATISTICS
# The amount of unique ids are:  27
#  ['AS14.01' 'AS14.02' 'AS14.03' 'AS14.05' 'AS14.06' 'AS14.07' 'AS14.08'
#  'AS14.09' 'AS14.12' 'AS14.13' 'AS14.14' 'AS14.15' 'AS14.16' 'AS14.17'
#  'AS14.19' 'AS14.20' 'AS14.23' 'AS14.24' 'AS14.25' 'AS14.26' 'AS14.27'
#  'AS14.28' 'AS14.29' 'AS14.30' 'AS14.31' 'AS14.32' 'AS14.33']
# Amount of unique days are:  113
#  ['2014-02-17' '2014-02-18' '2014-02-19' '2014-02-20' '2014-02-21'
#  '2014-02-22' '2014-02-25' '2014-02-26' '2014-02-27' '2014-02-28'
#  '2014-03-01' '2014-03-03' '2014-03-05' '2014-03-06' '2014-03-07'
#  '2014-03-10' '2014-03-11' '2014-03-12' '2014-03-13' '2014-03-14'
#  '2014-03-15' '2014-03-16' '2014-03-17' '2014-03-18' '2014-03-19'
#  '2014-03-20' '2014-03-21' '2014-03-22' '2014-03-23' '2014-03-24'
#  '2014-03-25' '2014-03-26' '2014-03-27' '2014-03-28' '2014-03-29'
#  '2014-03-30' '2014-03-31' '2014-04-01' '2014-04-02' '2014-04-03'
#  '2014-04-04' '2014-04-05' '2014-04-06' '2014-04-07' '2014-04-08'
#  '2014-04-09' '2014-04-10' '2014-04-11' '2014-04-12' '2014-04-13'
#  '2014-04-14' '2014-04-15' '2014-04-16' '2014-04-17' '2014-04-18'
#  '2014-04-19' '2014-04-20' '2014-04-21' '2014-04-22' '2014-04-23'
#  '2014-04-24' '2014-04-25' '2014-04-26' '2014-04-27' '2014-04-28'
#  '2014-04-29' '2014-04-30' '2014-05-01' '2014-05-02' '2014-05-03'
#  '2014-05-04' '2014-05-05' '2014-02-23' '2014-02-24' '2014-03-02'
#  '2014-03-04' '2014-03-08' '2014-03-09' '2014-05-06' '2014-05-07'
#  '2014-05-08' '2014-05-09' '2014-05-10' '2014-05-11' '2014-05-12'
#  '2014-05-13' '2014-05-14' '2014-05-15' '2014-05-16' '2014-05-17'
#  '2014-05-18' '2014-05-19' '2014-05-20' '2014-05-21' '2014-05-22'
#  '2014-05-23' '2014-05-24' '2014-05-25' '2014-05-26' '2014-05-27'
#  '2014-05-28' '2014-05-29' '2014-05-30' '2014-05-31' '2014-06-01'
#  '2014-06-02' '2014-06-03' '2014-06-04' '2014-06-05' '2014-06-06'
#  '2014-06-07' '2014-06-08' '2014-06-09']
#
# The variables used are:
#  ['call' 'sms' 'mood' 'circumplex.arousal' 'circumplex.valence' 'activity'
#  'screen' 'appCat.builtin' 'appCat.communication' 'appCat.entertainment'
#  'appCat.other' 'appCat.social' 'appCat.unknown' 'appCat.utilities'
#  'appCat.finance' 'appCat.office' 'appCat.travel' 'appCat.weather'
#  'appCat.game']
#
# Errors are within:  circumplex.valence 156 NA & circumplex.arousal 46 NA
# The count and amount of data inputs do not match
#
# How many data points per id:
# AS14.01  amount of data inputs:  21999
# AS14.02  amount of data inputs:  14581
# AS14.03  amount of data inputs:  14425
# AS14.05  amount of data inputs:  15745
# AS14.06  amount of data inputs:  18092
# AS14.07  amount of data inputs:  16045
# AS14.08  amount of data inputs:  7902
# AS14.09  amount of data inputs:  10886
# AS14.12  amount of data inputs:  17311
# AS14.13  amount of data inputs:  19592
# AS14.14  amount of data inputs:  9286
# AS14.15  amount of data inputs:  2848
# AS14.16  amount of data inputs:  3982
# AS14.17  amount of data inputs:  15826
# AS14.19  amount of data inputs:  11397
# AS14.20  amount of data inputs:  3620
# AS14.23  amount of data inputs:  21852
# AS14.24  amount of data inputs:  14430
# AS14.25  amount of data inputs:  12589
# AS14.26  amount of data inputs:  16403
# AS14.27  amount of data inputs:  14575
# AS14.28  amount of data inputs:  19276
# AS14.29  amount of data inputs:  17499
# AS14.30  amount of data inputs:  17279
# AS14.31  amount of data inputs:  11889
# AS14.32  amount of data inputs:  11193
# AS14.33  amount of data inputs:  16390
#
# How often are the variables used:
# call
# Amount of data inputs:  5239
#         value
# count  5239.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
#
# sms
# Amount of data inputs:  1798
#         value
# count  1798.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
#
# mood
# Amount of data inputs:  5641
#              value
# count  5641.000000
# mean      6.992555
# std       1.032769
# min       1.000000
# 25%       7.000000
# 50%       7.000000
# 75%       8.000000
# max      10.000000
#
# circumplex.arousal
# Amount of data inputs:  5643
#              value
# count  5597.000000
# mean     -0.098624
# std       1.051868
# min      -2.000000
# 25%      -1.000000
# 50%       0.000000
# 75%       1.000000
# max       2.000000
#
# circumplex.valence
# Amount of data inputs:  5643
#              value
# count  5487.000000
# mean      0.687808
# std       0.671298
# min      -2.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
#
# activity
# Amount of data inputs:  22965
#               value
# count  22965.000000
# mean       0.115958
# std        0.186946
# min        0.000000
# 25%        0.000000
# 50%        0.021739
# 75%        0.158333
# max        1.000000
#
# screen
# Amount of data inputs:  96578
#               value
# count  96578.000000
# mean      75.335206
# std      253.822497
# min        0.035000
# 25%        5.322250
# 50%       20.044500
# 75%       62.540250
# max     9867.007000
#
# appCat.builtin
# Amount of data inputs:  91288
#               value
# count  91288.000000
# mean      18.538262
# std      415.989243
# min   -82798.871000
# 25%        2.020000
# 50%        4.038000
# 75%        9.922000
# max    33960.246000
#
# appCat.communication
# Amount of data inputs:  74276
#               value
# count  74276.000000
# mean      43.343792
# std      128.912750
# min        0.006000
# 25%        5.218000
# 50%       16.225500
# 75%       45.475750
# max     9830.777000
#
# appCat.entertainment
# Amount of data inputs:  27125
#               value
# count  27125.000000
# mean      37.576480
# std      262.960476
# min       -0.011000
# 25%        1.334000
# 50%        3.391000
# 75%       14.922000
# max    32148.677000
#
# appCat.other
# Amount of data inputs:  7650
#              value
# count  7650.000000
# mean     25.810839
# std     112.781355
# min       0.014000
# 25%       7.019000
# 50%      10.028000
# 75%      16.829250
# max    3892.038000
#
# appCat.social
# Amount of data inputs:  19145
#               value
# count  19145.000000
# mean      72.401906
# std      261.551846
# min        0.094000
# 25%        9.030000
# 50%       28.466000
# 75%       75.372000
# max    30000.906000
#
# appCat.unknown
# Amount of data inputs:  939
#              value
# count   939.000000
# mean     45.553006
# std     119.400405
# min       0.111000
# 25%       5.018000
# 50%      17.190000
# 75%      44.430500
# max    2239.937000
#
# appCat.utilities
# Amount of data inputs:  2487
#              value
# count  2487.000000
# mean     18.537552
# std      60.959134
# min       0.246000
# 25%       3.158500
# 50%       8.030000
# 75%      19.331000
# max    1802.649000
#
# appCat.finance
# Amount of data inputs:  939
#             value
# count  939.000000
# mean    21.755251
# std     39.218361
# min      0.131000
# 25%      4.072000
# 50%      8.026000
# 75%     20.155000
# max    355.513000
#
# appCat.office
# Amount of data inputs:  5642
#               value
# count   5642.000000
# mean      22.578892
# std      449.601382
# min        0.003000
# 25%        2.004000
# 50%        3.106000
# 75%        8.043750
# max    32708.818000
#
# appCat.travel
# Amount of data inputs:  2846
#               value
# count   2846.000000
# mean      45.730850
# std      246.109307
# min        0.080000
# 25%        5.086500
# 50%       18.144000
# 75%       47.227250
# max    10452.615000
#
# appCat.weather
# Amount of data inputs:  255
#             value
# count  255.000000
# mean    20.148714
# std     24.943431
# min      1.003000
# 25%      8.684000
# 50%     15.117000
# 75%     25.349000
# max    344.863000
#
# appCat.game
# Amount of data inputs:  813
#              value
# count   813.000000
# mean    128.391615
# std     327.145246
# min       1.003000
# 25%      14.148000
# 50%      43.168000
# 75%     123.625000
# max    5491.793000

# %%
#plot the data points per id
fig, ax = plt.subplots()
ax.bar(np.arange(len(ids)),datalist,0.8,label='Amount of data')
ax.set_ylabel('#datapoints')
ax.set_title('Data points by user')
ax.set_xticks(np.arange(len(ids)))
ax.set_xticklabels(('AS14.01','AS14.02','AS14.03','AS14.05','AS14.06','AS14.07','AS14.08'
 ,'AS14.09', 'AS14.12', 'AS14.13','AS14.14','AS14.15','AS14.16','AS14.17',
 'AS14.19', 'AS14.20', 'AS14.23', 'AS14.24', 'AS14.25', 'AS14.26','AS14.27',
 'AS14.28', 'AS14.29', 'AS14.30','AS14.31','AS14.32','AS14.33'),rotation='vertical')
ax.legend()
plt.show()


#plot data points per variable
fig, bx = plt.subplots()
bx.bar(np.arange(len(inputs)),vardatalist,0.8,label='Amount of data')
bx.set_ylabel('#datapoints')
bx.set_title('Data points per input')
bx.set_xticks(np.arange(len(inputs)))
bx.set_xticklabels(('call','sms','mood','circumplex.arousal','circumplex.valence','activity'
 ,'screen','appCat.builtin','appCat.communication','appCat.entertainment'
 ,'appCat.other','appCat.social','appCat.unknown','appCat.utilities'
 ,'appCat.finance','appCat.office','appCat.travel','appCat.weather'
 ,'appCat.game'),rotation='vertical')
bx.legend()
plt.show()

# %%
#days over patients

# %%
# Clean data from NA
df = df.dropna(axis=0, how='any')

###Check to see the cleaning result
# print("\nHow often are the variables used:")
# for j in inputs:
#     print(j, "\nAmount of data inputs: ", len(df.loc[df['variable'] == j]))
#     print(df.loc[df['variable'] == j].describe(),"\n")
###
print(df)
# Out:
#               id        date          time            variable   value
# 136471   AS14.01  2014-02-17  12:04:42.394                call   1.000
# 136472   AS14.01  2014-02-17  18:28:25.520                call   1.000
# 136473   AS14.01  2014-02-18  09:29:51.257                call   1.000
# 136474   AS14.01  2014-02-19  14:43:30.575                call   1.000
# 136475   AS14.01  2014-02-19  17:29:10.378                call   1.000
# 136476   AS14.01  2014-02-19  17:42:16.499                call   1.000
# 136477   AS14.01  2014-02-19  17:43:18.061                call   1.000
# 136478   AS14.01  2014-02-19  17:44:01.594                call   1.000
# 136479   AS14.01  2014-02-19  18:07:50.055                call   1.000
# 136480   AS14.01  2014-02-19  18:10:06.385                call   1.000
# 141710   AS14.01  2014-02-19  17:42:34.292                 sms   1.000
# 141711   AS14.01  2014-02-19  21:25:04.397                 sms   1.000
# 136481   AS14.01  2014-02-20  13:42:05.309                call   1.000
# 136482   AS14.01  2014-02-20  13:42:56.997                call   1.000
# 141712   AS14.01  2014-02-20  10:58:33.924                 sms   1.000
# 141713   AS14.01  2014-02-20  11:13:44.448                 sms   1.000
# 141714   AS14.01  2014-02-20  11:16:45.930                 sms   1.000
# 141715   AS14.01  2014-02-21  15:36:58.253                 sms   1.000
# 136483   AS14.01  2014-02-22  17:34:44.325                call   1.000
# 136484   AS14.01  2014-02-22  18:17:55.618                call   1.000
# 141716   AS14.01  2014-02-22  22:32:39.631                 sms   1.000
# 136485   AS14.01  2014-02-25  11:27:52.973                call   1.000
# 136486   AS14.01  2014-02-25  11:38:26.127                call   1.000
# 136487   AS14.01  2014-02-25  12:29:25.009                call   1.000
# 1        AS14.01  2014-02-26  13:00:00.000                mood   6.000
# 2        AS14.01  2014-02-26  15:00:00.000                mood   6.000
# 3        AS14.01  2014-02-26  18:00:00.000                mood   6.000
# 4        AS14.01  2014-02-26  21:00:00.000                mood   7.000
# 5642     AS14.01  2014-02-26  13:00:00.000  circumplex.arousal  -1.000
# 5643     AS14.01  2014-02-26  15:00:00.000  circumplex.arousal  -1.000
# ...          ...         ...           ...                 ...     ...
# 2100468  AS14.33  2014-05-30  13:36:40.783       appCat.travel   7.024
# 2100533  AS14.33  2014-05-30  15:54:52.239       appCat.travel  30.536
# 2100534  AS14.33  2014-05-30  15:55:50.760       appCat.travel  77.831
# 2100535  AS14.33  2014-05-30  15:58:52.782       appCat.travel  24.128
# 2100536  AS14.33  2014-05-30  16:00:14.690       appCat.travel  11.175
# 2100537  AS14.33  2014-05-30  16:03:27.079       appCat.travel   8.067
# 2100539  AS14.33  2014-05-30  16:03:48.262       appCat.travel  62.029
# 2100540  AS14.33  2014-05-30  16:20:21.168       appCat.travel   5.701
# 2100541  AS14.33  2014-05-30  16:21:59.167       appCat.travel   5.048
# 2333842  AS14.33  2014-05-30  12:59:02.213      appCat.unknown   4.020
# 2333845  AS14.33  2014-05-30  12:59:43.450      appCat.unknown   1.006
# 2333859  AS14.33  2014-05-30  13:20:54.122      appCat.unknown   3.046
# 2567189  AS14.33  2014-05-30  10:08:55.105    appCat.utilities  11.361
# 2567190  AS14.33  2014-05-30  10:12:13.561    appCat.utilities  10.087
# 2567194  AS14.33  2014-05-30  10:16:56.842    appCat.utilities   4.085
# 2567196  AS14.33  2014-05-30  10:18:48.272    appCat.utilities   4.045
# 2567218  AS14.33  2014-05-30  10:48:07.361    appCat.utilities  22.564
# 2567219  AS14.33  2014-05-30  10:49:22.782    appCat.utilities  14.881
# 2567220  AS14.33  2014-05-30  10:49:37.673    appCat.utilities   6.332
# 2567221  AS14.33  2014-05-30  10:49:58.707    appCat.utilities  14.496
# 2567222  AS14.33  2014-05-30  10:50:59.608    appCat.utilities  14.452
# 2567223  AS14.33  2014-05-30  10:52:37.028    appCat.utilities  37.237
# 2567224  AS14.33  2014-05-30  10:53:14.276    appCat.utilities  76.903
# 2567225  AS14.33  2014-05-30  11:42:41.286    appCat.utilities   4.051
# 2567315  AS14.33  2014-05-30  15:05:58.599    appCat.utilities   4.306
# 2567367  AS14.33  2014-05-30  20:06:23.109    appCat.utilities   2.006
# 2567452  AS14.33  2014-05-30  22:32:05.016    appCat.utilities   6.019
# 5641     AS14.33  2014-05-31  12:00:00.000                mood   7.000
# 11284    AS14.33  2014-05-31  12:00:00.000  circumplex.arousal  -2.000
# 16927    AS14.33  2014-05-31  12:00:00.000  circumplex.valence   1.000
#
# [376710 rows x 5 columns]

# %%
#Write / load the data

fname = "adjusted_data.csv"
my_file = Path(fname)
if my_file.exists():
    print("file found, loading in now")
    df = pd.read_csv(fname, header=0, sep=',', index_col=0)
else:
    print("file not found")
    df = mergedays(df)
    df.to_csv(fname, sep=',')
    print("writing completed")

print(df)
# Out:
# file found, loading in now
#             id        date              variable        value
# 0      AS14.01  2014-02-17                  call     2.000000
# 1      AS14.01  2014-02-18                  call     1.000000
# 2      AS14.01  2014-02-19                  call     7.000000
# 3      AS14.01  2014-02-19                   sms     2.000000
# 4      AS14.01  2014-02-20                  call     2.000000
# 5      AS14.01  2014-02-20                   sms     3.000000
# 6      AS14.01  2014-02-21                   sms     1.000000
# 7      AS14.01  2014-02-22                  call     2.000000
# 8      AS14.01  2014-02-22                   sms     1.000000
# 9      AS14.01  2014-02-25                  call     3.000000
# 10     AS14.01  2014-02-26                  mood     6.250000
# 11     AS14.01  2014-02-26    circumplex.arousal    -0.250000
# 12     AS14.01  2014-02-26    circumplex.valence     0.750000
# 13     AS14.01  2014-02-26                  call     1.000000
# 14     AS14.01  2014-02-26                   sms     2.000000
# 15     AS14.01  2014-02-27                  mood     6.333333
# 16     AS14.01  2014-02-27    circumplex.arousal     0.000000
# 17     AS14.01  2014-02-27    circumplex.valence     0.333333
# 18     AS14.01  2014-02-28                  call     4.000000
# 19     AS14.01  2014-03-01                   sms     1.000000
# 20     AS14.01  2014-03-03                  call     1.000000
# 21     AS14.01  2014-03-05                  call     1.000000
# 22     AS14.01  2014-03-06                  call     1.000000
# 23     AS14.01  2014-03-07                  call     5.000000
# 24     AS14.01  2014-03-10                  call     1.000000
# 25     AS14.01  2014-03-11                  call     3.000000
# 26     AS14.01  2014-03-12                  call     7.000000
# 27     AS14.01  2014-03-12                   sms     1.000000
# 28     AS14.01  2014-03-13                  call     4.000000
# 29     AS14.01  2014-03-14                  call     3.000000
# ...        ...         ...                   ...          ...
# 15490  AS14.33  2014-05-29    circumplex.arousal    -1.333333
# 15491  AS14.33  2014-05-29    circumplex.valence     1.000000
# 15492  AS14.33  2014-05-29              activity     4.064507
# 15493  AS14.33  2014-05-29                screen  3569.341000
# 15494  AS14.33  2014-05-29                  call     5.000000
# 15495  AS14.33  2014-05-29                   sms     1.000000
# 15496  AS14.33  2014-05-29        appCat.builtin   400.034000
# 15497  AS14.33  2014-05-29  appCat.communication   435.105000
# 15498  AS14.33  2014-05-29  appCat.entertainment   136.738000
# 15499  AS14.33  2014-05-29          appCat.other    29.202000
# 15500  AS14.33  2014-05-29         appCat.social  1789.922000
# 15501  AS14.33  2014-05-29         appCat.travel     0.939000
# 15502  AS14.33  2014-05-29      appCat.utilities     3.199000
# 15503  AS14.33  2014-05-30                  mood     6.800000
# 15504  AS14.33  2014-05-30    circumplex.arousal    -0.800000
# 15505  AS14.33  2014-05-30    circumplex.valence    -0.400000
# 15506  AS14.33  2014-05-30              activity     4.050925
# 15507  AS14.33  2014-05-30                screen  9497.646999
# 15508  AS14.33  2014-05-30                  call     4.000000
# 15509  AS14.33  2014-05-30        appCat.builtin  3044.030000
# 15510  AS14.33  2014-05-30  appCat.communication  1670.842000
# 15511  AS14.33  2014-05-30  appCat.entertainment   260.220000
# 15512  AS14.33  2014-05-30          appCat.other    52.610000
# 15513  AS14.33  2014-05-30         appCat.social  3166.409000
# 15514  AS14.33  2014-05-30         appCat.travel  1052.648000
# 15515  AS14.33  2014-05-30        appCat.unknown     8.072000
# 15516  AS14.33  2014-05-30      appCat.utilities   232.825000
# 15517  AS14.33  2014-05-31                  mood     7.000000
# 15518  AS14.33  2014-05-31    circumplex.arousal    -2.000000
# 15519  AS14.33  2014-05-31    circumplex.valence     1.000000
#
# [15520 rows x 4 columns]

# %%
# Feli
#TODO benchmark x=y

# %%
#Model one  Michael

# %%
# Import libraries
from pandas import Series
from pandas.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
#Model two Cecilia
# Get the information of patient 1
# Write it to csv file
#p_1=df.loc[df['id']=='AS14.01']
#p_1.to_csv('patient_1.csv', sep=',')
p_1 = pd.read_csv('patient_1.csv', header=0, sep=',', index_col=0)
# check the time_series and drop unnecessary datapoints
p_1 = p_1.groupby(['date','variable']).mean().squeeze().unstack().add_suffix('')
mood=p_1.loc[p_1['variable']=='mood']
mood=mood.drop(mood.index[[0,1]])
mood=mood.drop(columns=['id', 'variable'])
mood['value']=mood['value'].astype(float)
mood['date']=pd.to_datetime(mood['date'])
mood.set_index('date', inplace=True)

# %%
mood.to_csv('patient_1_mood.csv')

# %%
mood=Series.from_csv('patient_1_mood.csv', header=0)
# Out:
# /home/cecilia/miniconda3/envs/ml1labs/lib/python3.6/site-packages/pandas/core/series.py:2890: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)

# %%
fig_auto=autocorrelation_plot(mood.values)
plt.show(fig_auto)

# %%
ax2 = fig.add_subplot(212)
fig=plot_pacf(mood)
plt.show()

# %%
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=7,center=False).mean()
    rolstd = timeseries.rolling(window=7,center=False).std()
    plt.figure()
    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    #Decompose the trend
    plt.figure()
    decompose=seasonal_decompose(timeseries)
    dec=decompose.plot()
    dec.set_size_inches(25,16)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(mood)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.679622
# p-value                         0.004409
# #Lags Used                      0.000000
# Number of Observations Used    44.000000
# Critical Value (1%)            -3.588573
# Critical Value (5%)            -2.929886
# Critical Value (10%)           -2.603185
# dtype: float64

# %%
#Runing the ARIMA models
#def arima_model(timeseries, p,d,)
model=ARIMA(endog=mood,order=(5,1,1))
results=model.fit()
print(results.summary())
# Out:
# /home/cecilia/miniconda3/envs/ml1labs/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.value   No. Observations:                   44
# Model:                 ARIMA(5, 1, 1)   Log Likelihood                 -25.587
# Method:                       css-mle   S.D. of innovations              0.412
# Date:                Thu, 19 Apr 2018   AIC                             67.174
# Time:                        17:32:40   BIC                             81.448
# Sample:                    03-22-2014   HQIC                            72.468
#                          - 05-04-2014
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0290      0.005      6.030      0.000       0.020       0.038
# ar.L1.D.value     0.1596      0.142      1.126      0.268      -0.118       0.437
# ar.L2.D.value     0.0569      0.142      0.400      0.691      -0.222       0.335
# ar.L3.D.value     0.0007      0.142      0.005      0.996      -0.277       0.278
# ar.L4.D.value     0.0217      0.145      0.150      0.882      -0.263       0.307
# ar.L5.D.value    -0.3106      0.142     -2.192      0.035      -0.588      -0.033
# ma.L1.D.value    -1.0000      0.070    -14.376      0.000      -1.136      -0.864
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0289           -0.6684j            1.2269           -0.0917
# AR.2            1.0289           +0.6684j            1.2269            0.0917
# AR.3           -1.2770           -0.0000j            1.2770           -0.5000
# AR.4           -0.3554           -1.2445j            1.2942           -0.2943
# AR.5           -0.3554           +1.2445j            1.2942            0.2943
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# /home/cecilia/miniconda3/envs/ml1labs/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):

# %%
# plot residual errors
residuals = pd.DataFrame(results.resid)
residuals.plot()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
# /home/cecilia/miniconda3/envs/ml1labs/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
#                0
# count  45.000000
# mean    0.018182
# std     0.488416
# min    -1.338710
# 25%    -0.249985
# 50%     0.046624
# 75%     0.286594
# max     1.104071

# %%
results.plot_predict()
# Out:
# /home/cecilia/miniconda3/envs/ml1labs/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):

# %%
# Training and predicting

def arima_t_p(timeseries, p, d, q, percent):
    X = timeseries.values
    size = int(len(X) * percent)
    train, test = X[0:size], X[size:len(X)]
    history = [x for x in train]
    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=(p,d,q))
        model_fit = model.fit(disp=0)        
        output = model_fit.forecast()
        yhat = output[0]
        predictions.append(yhat)
        obs = test[t]
        history.append(obs)
        print('predicted=%f, expected=%f' % (yhat, obs))
    error = mean_squared_error(test, predictions)
    print('Test MSE: %.3f' % error)
    # plot
    E=plt.plot(test, label='expectation')
    P=plt.plot(predictions, color='red', label='prediction')
    plt.legend()
    plt.show()
    return test, predictions, error

# %%
arima_t_p(mood, 5, 1, 1, 0.8)
# Out:
# /home/cecilia/miniconda3/envs/ml1labs/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /home/cecilia/miniconda3/envs/ml1labs/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /home/cecilia/miniconda3/envs/ml1labs/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# predicted=7.308087, expected=7.600000
# predicted=7.467696, expected=7.500000
# predicted=7.462095, expected=7.600000
# predicted=7.498003, expected=7.000000
# predicted=7.529140, expected=7.800000
# predicted=7.522672, expected=8.000000
# predicted=7.735646, expected=7.600000
# predicted=7.627106, expected=8.000000
# predicted=7.946092, expected=8.000000
# Test MSE: 0.091
# (array([7.6, 7.5, 7.6, 7. , 7.8, 8. , 7.6, 8. , 8. ]),
#  [array([7.30808715]),
#   array([7.46769568]),
#   array([7.4620947]),
#   array([7.49800275]),
#   array([7.52914028]),
#   array([7.52267156]),
#   array([7.73564558]),
#   array([7.62710634]),
#   array([7.94609173])],
#  0.09053824776951111)

# %%
# Analyse based on other variables SARIMAX
# Granger causality test
def g_c(data):
    for k in data.columns:
        print('\n')
        print(k)
        print(grangercausalitytests(data[['mood', k]].dropna(),1))
        print(grangercausalitytests(data[[k, 'mood']].dropna(),1))
        print('\n')
g_c(p_1)
# Out:
# activity
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.0017  , p=0.0308  , df_denom=41, df_num=1
# ssr based chi2 test:   chi2=5.3677  , p=0.0205  , df=1
# likelihood ratio test: chi2=5.0647  , p=0.0244  , df=1
# parameter F test:         F=5.0017  , p=0.0308  , df_denom=41, df_num=1
# {1: ({'ssr_ftest': (5.001679136582905, 0.03082480675299156, 41.0, 1), 'ssr_chi2test': (5.367655658771898, 0.020513530313500155, 1), 'lrtest': (5.064656611861594, 0.024418542672440254, 1), 'params_ftest': (5.001679136582892, 0.03082480675299184, 41.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe0903beb38>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090437c88>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2214  , p=0.6405  , df_denom=41, df_num=1
# ssr based chi2 test:   chi2=0.2376  , p=0.6260  , df=1
# likelihood ratio test: chi2=0.2369  , p=0.6264  , df=1
# parameter F test:         F=0.2214  , p=0.6405  , df_denom=41, df_num=1
# {1: ({'ssr_ftest': (0.22137554269559573, 0.6404873003790756, 41.0, 1), 'ssr_chi2test': (0.23757375313673687, 0.6259639961414085, 1), 'lrtest': (0.23693467425965054, 0.6264288736983089, 1), 'params_ftest': (0.22137554269559073, 0.6404873003790792, 41.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe08b8b64e0>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe08b8fed30>, array([[0., 1., 0.]])])}
#
#
#
#
# appCat.builtin
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.6051  , p=0.2123  , df_denom=41, df_num=1
# ssr based chi2 test:   chi2=1.7225  , p=0.1894  , df=1
# likelihood ratio test: chi2=1.6897  , p=0.1936  , df=1
# parameter F test:         F=1.6051  , p=0.2123  , df_denom=41, df_num=1
# {1: ({'ssr_ftest': (1.6050737190888236, 0.21233535098516917, 41.0, 1), 'ssr_chi2test': (1.7225181375587373, 0.18936922782388596, 1), 'lrtest': (1.689656358107186, 0.19364627492592176, 1), 'params_ftest': (1.6050737190888118, 0.21233535098516915, 41.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090276828>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe0903684e0>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0584  , p=0.8103  , df_denom=41, df_num=1
# ssr based chi2 test:   chi2=0.0626  , p=0.8024  , df=1
# likelihood ratio test: chi2=0.0626  , p=0.8025  , df=1
# parameter F test:         F=0.0584  , p=0.8103  , df_denom=41, df_num=1
# {1: ({'ssr_ftest': (0.05835361213243165, 0.8103214154964783, 41.0, 1), 'ssr_chi2test': (0.06262338862992664, 0.8023966068183837, 1), 'lrtest': (0.06257886622401543, 0.8024654092770795, 1), 'params_ftest': (0.058353612132422024, 0.8103214154964855, 41.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe08b9050f0>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090368e80>, array([[0., 1., 0.]])])}
#
#
#
#
# appCat.communication
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0910  , p=0.7644  , df_denom=41, df_num=1
# ssr based chi2 test:   chi2=0.0977  , p=0.7546  , df=1
# likelihood ratio test: chi2=0.0976  , p=0.7548  , df=1
# parameter F test:         F=0.0910  , p=0.7644  , df_denom=41, df_num=1
# {1: ({'ssr_ftest': (0.0910185970776749, 0.7644111896043687, 41.0, 1), 'ssr_chi2test': (0.09767849442482185, 0.7546335204689681, 1), 'lrtest': (0.09757023316160485, 0.7547651657222177, 1), 'params_ftest': (0.09101859707767535, 0.7644111896043687, 41.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090437cf8>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090437128>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3708  , p=0.5459  , df_denom=41, df_num=1
# ssr based chi2 test:   chi2=0.3979  , p=0.5282  , df=1
# likelihood ratio test: chi2=0.3962  , p=0.5291  , df=1
# parameter F test:         F=0.3708  , p=0.5459  , df_denom=41, df_num=1
# {1: ({'ssr_ftest': (0.370816066110362, 0.545919294400717, 41.0, 1), 'ssr_chi2test': (0.39794894899648603, 0.5281504104294552, 1), 'lrtest': (0.3961601428611772, 0.5290790117970701, 1), 'params_ftest': (0.37081606611134255, 0.5459192944001874, 41.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe0903602b0>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090437c88>, array([[0., 1., 0.]])])}
#
#
#
#
# appCat.entertainment
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.9020  , p=0.0324  , df_denom=41, df_num=1
# ssr based chi2 test:   chi2=5.2607  , p=0.0218  , df=1
# likelihood ratio test: chi2=4.9692  , p=0.0258  , df=1
# parameter F test:         F=4.9020  , p=0.0324  , df_denom=41, df_num=1
# {1: ({'ssr_ftest': (4.901969367049322, 0.032445802406981895, 41.0, 1), 'ssr_chi2test': (5.260650052443174, 0.021812870115595136, 1), 'lrtest': (4.969182021846791, 0.025802847433528488, 1), 'params_ftest': (4.901969367049309, 0.03244580240698199, 41.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe0903c8f28>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe0903684a8>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0687  , p=0.7946  , df_denom=41, df_num=1
# ssr based chi2 test:   chi2=0.0737  , p=0.7860  , df=1
# likelihood ratio test: chi2=0.0737  , p=0.7861  , df=1
# parameter F test:         F=0.0687  , p=0.7946  , df_denom=41, df_num=1
# {1: ({'ssr_ftest': (0.0686905849054132, 0.7945652543744876, 41.0, 1), 'ssr_chi2test': (0.07371672526434588, 0.7860001618028808, 1), 'lrtest': (0.07365504238156717, 0.786087535739538, 1), 'params_ftest': (0.0686905849054447, 0.7945652543744341, 41.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe0902e9358>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090368f98>, array([[0., 1., 0.]])])}
#
#
#
#
# appCat.finance
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.8857  , p=0.0587  , df_denom=28, df_num=1
# ssr based chi2 test:   chi2=4.3020  , p=0.0381  , df=1
# likelihood ratio test: chi2=4.0285  , p=0.0447  , df=1
# parameter F test:         F=3.8857  , p=0.0587  , df_denom=28, df_num=1
# {1: ({'ssr_ftest': (3.8856727235909694, 0.058656134965915395, 28.0, 1), 'ssr_chi2test': (4.301994801118573, 0.038067696931334945, 1), 'lrtest': (4.028520301929575, 0.044737162743809476, 1), 'params_ftest': (3.8856727235909685, 0.058656134965915395, 28.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090368e80>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090360748>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9955  , p=0.3269  , df_denom=28, df_num=1
# ssr based chi2 test:   chi2=1.1022  , p=0.2938  , df=1
# likelihood ratio test: chi2=1.0830  , p=0.2980  , df=1
# parameter F test:         F=0.9955  , p=0.3269  , df_denom=28, df_num=1
# {1: ({'ssr_ftest': (0.9955083638989557, 0.32694483253083007, 28.0, 1), 'ssr_chi2test': (1.102169974316701, 0.2937903784179384, 1), 'lrtest': (1.0830291381726198, 0.2980209041307795, 1), 'params_ftest': (0.9955083638989008, 0.3269448325308436, 28.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe0902e9358>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe0900b69e8>, array([[0., 1., 0.]])])}
#
#
#
#
# appCat.other
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8750  , p=0.3551  , df_denom=41, df_num=1
# ssr based chi2 test:   chi2=0.9390  , p=0.3325  , df=1
# likelihood ratio test: chi2=0.9291  , p=0.3351  , df=1
# parameter F test:         F=0.8750  , p=0.3551  , df_denom=41, df_num=1
# {1: ({'ssr_ftest': (0.8749751009392642, 0.3550586986534692, 41.0, 1), 'ssr_chi2test': (0.9389976693006739, 0.33253574883205883, 1), 'lrtest': (0.9291184687976966, 0.33509209521388683, 1), 'params_ftest': (0.8749751009392507, 0.35505869865347295, 41.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090360f60>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090354c50>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0740  , p=0.7870  , df_denom=41, df_num=1
# ssr based chi2 test:   chi2=0.0794  , p=0.7781  , df=1
# likelihood ratio test: chi2=0.0793  , p=0.7782  , df=1
# parameter F test:         F=0.0740  , p=0.7870  , df_denom=41, df_num=1
# {1: ({'ssr_ftest': (0.07397459231388111, 0.7870003019284102, 41.0, 1), 'ssr_chi2test': (0.07938736736123826, 0.7781293542809234, 1), 'lrtest': (0.07931583572912615, 0.7782267184993918, 1), 'params_ftest': (0.0739745923139252, 0.7870003019283461, 41.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe08b8b6198>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe0903c8f28>, array([[0., 1., 0.]])])}
#
#
#
#
# appCat.social
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0018  , p=0.9665  , df_denom=41, df_num=1
# ssr based chi2 test:   chi2=0.0019  , p=0.9651  , df=1
# likelihood ratio test: chi2=0.0019  , p=0.9651  , df=1
# parameter F test:         F=0.0018  , p=0.9665  , df_denom=41, df_num=1
# {1: ({'ssr_ftest': (0.001785923965337127, 0.9664964162141051, 41.0, 1), 'ssr_chi2test': (0.0019166013286544777, 0.9650805621650815, 1), 'lrtest': (0.0019165595872436825, 0.9650809421772306, 1), 'params_ftest': (0.0017859239653473008, 0.966496416213977, 41.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe08b8b65c0>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090360f28>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6075  , p=0.4402  , df_denom=41, df_num=1
# ssr based chi2 test:   chi2=0.6519  , p=0.4194  , df=1
# likelihood ratio test: chi2=0.6471  , p=0.4211  , df=1
# parameter F test:         F=0.6075  , p=0.4402  , df_denom=41, df_num=1
# {1: ({'ssr_ftest': (0.6074614316896318, 0.44022110923130686, 41.0, 1), 'ssr_chi2test': (0.6519098291303366, 0.4194306923180472, 1), 'lrtest': (0.6471276160043331, 0.421141507576687, 1), 'params_ftest': (0.6074614316895758, 0.44022110923132607, 41.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe0900b69e8>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe08b8b6278>, array([[0., 1., 0.]])])}
#
#
#
#
# appCat.travel
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1286  , p=0.7235  , df_denom=21, df_num=1
# ssr based chi2 test:   chi2=0.1469  , p=0.7015  , df=1
# likelihood ratio test: chi2=0.1465  , p=0.7019  , df=1
# parameter F test:         F=0.1286  , p=0.7235  , df_denom=21, df_num=1
# {1: ({'ssr_ftest': (0.1285739809519122, 0.7234948037082337, 21.0, 1), 'ssr_chi2test': (0.14694169251647107, 0.7014752880854298, 1), 'lrtest': (0.14649368976796495, 0.7019088891104868, 1), 'params_ftest': (0.12857398095191083, 0.7234948037082362, 21.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe0903b2860>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090360f28>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4795  , p=0.4963  , df_denom=21, df_num=1
# ssr based chi2 test:   chi2=0.5480  , p=0.4592  , df=1
# likelihood ratio test: chi2=0.5418  , p=0.4617  , df=1
# parameter F test:         F=0.4795  , p=0.4963  , df_denom=21, df_num=1
# {1: ({'ssr_ftest': (0.47946261997074696, 0.4962520564836922, 21.0, 1), 'ssr_chi2test': (0.5479572799665678, 0.459153551681895, 1), 'lrtest': (0.5417955338893492, 0.46168955017282864, 1), 'params_ftest': (0.4794626199707459, 0.4962520564836922, 21.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe08b8b65c0>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090360240>, array([[0., 1., 0.]])])}
#
#
#
#
# appCat.utilities
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3829  , p=0.5397  , df_denom=39, df_num=1
# ssr based chi2 test:   chi2=0.4123  , p=0.5208  , df=1
# likelihood ratio test: chi2=0.4103  , p=0.5218  , df=1
# parameter F test:         F=0.3829  , p=0.5397  , df_denom=39, df_num=1
# {1: ({'ssr_ftest': (0.38286274016459154, 0.5396726574852728, 39.0, 1), 'ssr_chi2test': (0.4123137201772524, 0.5207974823852473, 1), 'lrtest': (0.4103030282453801, 0.5218157402616312, 1), 'params_ftest': (0.3828627401645887, 0.5396726574852728, 39.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090360eb8>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe0900b69e8>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.1399  , p=0.2922  , df_denom=39, df_num=1
# ssr based chi2 test:   chi2=1.2276  , p=0.2679  , df=1
# likelihood ratio test: chi2=1.2100  , p=0.2713  , df=1
# parameter F test:         F=1.1399  , p=0.2922  , df_denom=39, df_num=1
# {1: ({'ssr_ftest': (1.1399318279970918, 0.2922313287670549, 39.0, 1), 'ssr_chi2test': (1.2276188916891757, 0.26787060717542854, 1), 'lrtest': (1.2100199530135995, 0.2713281702856271, 1), 'params_ftest': (1.1399318279975916, 0.2922313287669473, 39.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe0903d2d30>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090360f28>, array([[0., 1., 0.]])])}
#
#
#
#
# call
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3717  , p=0.5470  , df_denom=28, df_num=1
# ssr based chi2 test:   chi2=0.4116  , p=0.5212  , df=1
# likelihood ratio test: chi2=0.4089  , p=0.5225  , df=1
# parameter F test:         F=0.3717  , p=0.5470  , df_denom=28, df_num=1
# {1: ({'ssr_ftest': (0.37174113102588696, 0.5469731581974273, 28.0, 1), 'ssr_chi2test': (0.4115705379215177, 0.521173436857219, 1), 'lrtest': (0.4088623797036348, 0.5225474819100866, 1), 'params_ftest': (0.3717411310258892, 0.546973158197424, 28.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe08b8fe7f0>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe08b8b6eb8>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0725  , p=0.7898  , df_denom=28, df_num=1
# ssr based chi2 test:   chi2=0.0802  , p=0.7770  , df=1
# likelihood ratio test: chi2=0.0801  , p=0.7771  , df=1
# parameter F test:         F=0.0725  , p=0.7898  , df_denom=28, df_num=1
# {1: ({'ssr_ftest': (0.07245758426377931, 0.7897652611167056, 28.0, 1), 'ssr_chi2test': (0.08022089686346995, 0.776998281196678, 1), 'lrtest': (0.08011727893470777, 0.7771385409365359, 1), 'params_ftest': (0.07245758426377659, 0.7897652611167101, 28.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090437c88>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090360240>, array([[0., 1., 0.]])])}
#
#
#
#
# circumplex.arousal
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.7998  , p=0.0578  , df_denom=43, df_num=1
# ssr based chi2 test:   chi2=4.0649  , p=0.0438  , df=1
# likelihood ratio test: chi2=3.8952  , p=0.0484  , df=1
# parameter F test:         F=3.7998  , p=0.0578  , df_denom=43, df_num=1
# {1: ({'ssr_ftest': (3.799762381400355, 0.057801713876650944, 43.0, 1), 'ssr_chi2test': (4.064862082428287, 0.04378426032424376, 1), 'lrtest': (3.895188455245588, 0.04842460603645572, 1), 'params_ftest': (3.799762381400342, 0.057801713876651485, 43.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090360240>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe0900b69e8>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3388  , p=0.5635  , df_denom=43, df_num=1
# ssr based chi2 test:   chi2=0.3625  , p=0.5471  , df=1
# likelihood ratio test: chi2=0.3611  , p=0.5479  , df=1
# parameter F test:         F=0.3388  , p=0.5635  , df_denom=43, df_num=1
# {1: ({'ssr_ftest': (0.338835268050597, 0.5635420232612157, 43.0, 1), 'ssr_chi2test': (0.3624749379145921, 0.5471349209697536, 1), 'lrtest': (0.3610542648880397, 0.5479213060225117, 1), 'params_ftest': (0.3388352680505984, 0.5635420232612101, 43.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe08b8b6eb8>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090319c50>, array([[0., 1., 0.]])])}
#
#
#
#
# circumplex.valence
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.8034  , p=0.1013  , df_denom=43, df_num=1
# ssr based chi2 test:   chi2=2.9990  , p=0.0833  , df=1
# likelihood ratio test: chi2=2.9053  , p=0.0883  , df=1
# parameter F test:         F=2.8034  , p=0.1013  , df_denom=43, df_num=1
# {1: ({'ssr_ftest': (2.8033774183752467, 0.10132554396465346, 43.0, 1), 'ssr_chi2test': (2.9989618894246823, 0.08331788720708642, 1), 'lrtest': (2.905254911481933, 0.08829129380714135, 1), 'params_ftest': (2.8033774183752542, 0.10132554396465315, 43.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090319c50>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090360f28>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.5189  , p=0.0393  , df_denom=43, df_num=1
# ssr based chi2 test:   chi2=4.8342  , p=0.0279  , df=1
# likelihood ratio test: chi2=4.5967  , p=0.0320  , df=1
# parameter F test:         F=4.5189  , p=0.0393  , df_denom=43, df_num=1
# {1: ({'ssr_ftest': (4.518888888294901, 0.039305500283770695, 43.0, 1), 'ssr_chi2test': (4.834160206082918, 0.0279012267108237, 1), 'lrtest': (4.5966501469283685, 0.032034491078697054, 1), 'params_ftest': (4.51888888829489, 0.03930550028377093, 43.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe08b8b6eb8>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090374da0>, array([[0., 1., 0.]])])}
#
#
#
#
# mood
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=-0.0000 , p=1.0000  , df_denom=44, df_num=1
# ssr based chi2 test:   chi2=-0.0000 , p=1.0000  , df=1
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=1
# parameter F test:         F=19.0914 , p=0.0001  , df_denom=44, df_num=1
# {1: ({'ssr_ftest': (-2.0874040761968415e-14, 1.0, 44.0, 1), 'ssr_chi2test': (-2.1822860796603343e-14, 1.0, 1), 'lrtest': (-1.4210854715202004e-14, 1.0, 1), 'params_ftest': (19.09137781090689, 7.487065027743969e-05, 44.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090360240>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe09012dd68>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=-0.0000 , p=1.0000  , df_denom=44, df_num=1
# ssr based chi2 test:   chi2=-0.0000 , p=1.0000  , df=1
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=1
# parameter F test:         F=19.0914 , p=0.0001  , df_denom=44, df_num=1
# {1: ({'ssr_ftest': (-2.0874040761968415e-14, 1.0, 44.0, 1), 'ssr_chi2test': (-2.1822860796603343e-14, 1.0, 1), 'lrtest': (-1.4210854715202004e-14, 1.0, 1), 'params_ftest': (19.09137781090689, 7.487065027743969e-05, 44.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe08b8b6eb8>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe090374da0>, array([[0., 1., 0.]])])}
#
#
#
#
# screen
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2336  , p=0.6315  , df_denom=41, df_num=1
# ssr based chi2 test:   chi2=0.2506  , p=0.6166  , df=1
# likelihood ratio test: chi2=0.2499  , p=0.6171  , df=1
# parameter F test:         F=0.2336  , p=0.6315  , df_denom=41, df_num=1
# {1: ({'ssr_ftest': (0.23355211675889356, 0.6314732753769242, 41.0, 1), 'ssr_chi2test': (0.25064129603393454, 0.6166238827926276, 1), 'lrtest': (0.2499301198415651, 0.6171242865122176, 1), 'params_ftest': (0.23355211675889193, 0.6314732753769242, 41.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe09034eb00>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe09012dd68>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.1805  , p=0.2836  , df_denom=41, df_num=1
# ssr based chi2 test:   chi2=1.2669  , p=0.2604  , df=1
# likelihood ratio test: chi2=1.2490  , p=0.2638  , df=1
# parameter F test:         F=1.1805  , p=0.2836  , df_denom=41, df_num=1
# {1: ({'ssr_ftest': (1.1804790118296578, 0.28360516216202486, 41.0, 1), 'ssr_chi2test': (1.2668555248903643, 0.26035741117863004, 1), 'lrtest': (1.248960444830061, 0.2637511195918422, 1), 'params_ftest': (1.1804790118296142, 0.2836051621620335, 41.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe09015b5f8>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe09015bd30>, array([[0., 1., 0.]])])}
#
#
#
#
# sms
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2650  , p=0.6179  , df_denom=10, df_num=1
# ssr based chi2 test:   chi2=0.3445  , p=0.5572  , df=1
# likelihood ratio test: chi2=0.3400  , p=0.5598  , df=1
# parameter F test:         F=0.2650  , p=0.6179  , df_denom=10, df_num=1
# {1: ({'ssr_ftest': (0.2650082858243801, 0.6178858613147591, 10.0, 1), 'ssr_chi2test': (0.3445107715716941, 0.5572370193897545, 1), 'lrtest': (0.3400249406889273, 0.5598148260337249, 1), 'params_ftest': (0.26500828582437885, 0.6178858613147591, 10.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe09015bdd8>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe09015bb00>, array([[0., 1., 0.]])])}
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.6669  , p=0.1335  , df_denom=10, df_num=1
# ssr based chi2 test:   chi2=3.4670  , p=0.0626  , df=1
# likelihood ratio test: chi2=3.0733  , p=0.0796  , df=1
# parameter F test:         F=2.6669  , p=0.1335  , df_denom=10, df_num=1
# {1: ({'ssr_ftest': (2.6669371265850588, 0.13350209025101084, 10.0, 1), 'ssr_chi2test': (3.4670182645605765, 0.06260406433902191, 1), 'lrtest': (3.0733316891562765, 0.0795862102249584, 1), 'params_ftest': (2.66693712658505, 0.1335020902510113, 10.0, 1)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe09034eb00>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe09015b9b0>, array([[0., 1., 0.]])])}

# %%
mood_other=p_1[['activity','appCat.entertainment', 'appCat.finance','circumplex.arousal','circumplex.valence','mood']]
#interpolate the missing values
for j in mood_other.columns:
     mood_other[j]=mood_other[j].interpolate()
mood_other=mood_other.dropna()
# Out:
# /home/cecilia/miniconda3/envs/ml1labs/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
endog=mood_other['mood']
exog=mood_other[['appCat.entertainment', 'circumplex.arousal','circumplex.valence' ]]

# %%
mod=SARIMAX(endog=mood_other['mood'],exog=exog, order=(7,1,2))
res = mod.fit(disp=False)
prediction=res.get_prediction()
print(res.summary())
mse=mean_squared_error(endog[30:40], prediction.predicted_mean[30:40])
print(mse)
# Out:
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                   mood   No. Observations:                   46
# Model:               SARIMAX(7, 1, 2)   Log Likelihood                 -16.753
# Date:                Fri, 20 Apr 2018   AIC                             59.507
# Time:                        00:51:49   BIC                             83.279
# Sample:                    03-21-2014   HQIC                            68.412
#                          - 05-05-2014
# Covariance Type:                  opg
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# appCat.entertainment  3.739e-05   6.68e-05      0.560      0.576   -9.35e-05       0.000
# circumplex.arousal      -0.0260      0.140     -0.185      0.853      -0.300       0.248
# circumplex.valence       1.0450      0.250      4.185      0.000       0.556       1.534
# ar.L1                   -0.3531      4.146     -0.085      0.932      -8.478       7.772
# ar.L2                   -0.0974      1.946     -0.050      0.960      -3.911       3.716
# ar.L3                    0.0463      1.410      0.033      0.974      -2.718       2.810
# ar.L4                   -0.0646      0.698     -0.093      0.926      -1.433       1.303
# ar.L5                   -0.1166      0.773     -0.151      0.880      -1.632       1.399
# ar.L6                   -0.1960      0.857     -0.229      0.819      -1.875       1.483
# ar.L7                    0.0723      1.262      0.057      0.954      -2.401       2.546
# ma.L1                   -0.4340      4.209     -0.103      0.918      -8.684       7.816
# ma.L2                   -0.1468      1.786     -0.082      0.935      -3.648       3.354
# sigma2                   0.1152      0.029      4.008      0.000       0.059       0.171
# ===================================================================================
# Ljung-Box (Q):                       25.94   Jarque-Bera (JB):                 1.46
# Prob(Q):                              0.96   Prob(JB):                         0.48
# Heteroskedasticity (H):               0.47   Skew:                            -0.15
# Prob(H) (two-sided):                  0.15   Kurtosis:                         3.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# 0.04372691725611926

# %%
res.plot_diagnostics(figsize=(15, 12))

# %%
A=plt.plot(endog.values, label='Expected')
B=plt.plot(prediction.predicted_mean.values[1:46], label='Forecasted')
plt.legend()
plt.show()
