# %%
import numpy as np
import pandas as pd

# %%
#filenames
LM_scores_ranking_filename = "VU_test_data_assigned_scores_ranking_LM.txt"
out_LM_ranking_list_filename = "VU_test_data_ranking_list.txt"

# %%
# Load assigned scores file
df_ranking = pd.read_csv(LM_scores_ranking_filename, names=['SearchId','X','PropertyId','rank','score','Y'], sep=' ')

# %%
df_ranking = df_ranking[['SearchId','PropertyId']]

# %%
df_ranking
# Out:
#          SearchId  PropertyId
# 0               1       61934
# 1               1       99484
# 2               1       54937
# 3               1       63894
# 4               1       73666
# 5               1       94729
# 6               1      123675
# 7               1       28181
# 8               1       24194
# 9               1       82231
# 10              1       74045
# 11              1       78599
# 12              1       34263
# 13              1       56050
# 14              1        5543
# 15              1        3180
# 16              1       50162
# 17              1      139162
# 18              1      134992
# 19              1       95031
# 20              1       22393
# 21              1       90385
# 22              1      128085
# 23              1       89466
# 24              1       37567
# 25              1       14142
# 26              1       72090
# 27              1      128871
# 28              1       61632
# 29              3      131940
# ...

# %%
df_ranking[df_ranking['SearchId'] == 1]
# Out:
#     SearchId  PropertyId
# 0          1       61934
# 1          1       99484
# 2          1       54937
# 3          1       63894
# 4          1       73666
# 5          1       94729
# 6          1      123675
# 7          1       28181
# 8          1       24194
# 9          1       82231
# 10         1       74045
# 11         1       78599
# 12         1       34263
# 13         1       56050
# 14         1        5543
# 15         1        3180
# 16         1       50162
# 17         1      139162
# 18         1      134992
# 19         1       95031
# 20         1       22393
# 21         1       90385
# 22         1      128085
# 23         1       89466
# 24         1       37567
# 25         1       14142
# 26         1       72090
# 27         1      128871
# 28         1       61632

# %%
df_ranking.to_csv(out_LM_ranking_list_filename, header=True, index=False)
