# %%
import numpy as np
import pandas as pd

# %%
df_test = pd.read_csv("test1.csv", sep=',')

# %%
df_test = df_test[['srch_id','prop_id']]

# %%
df_test = df_test.iloc[np.random.permutation(df_test.shape[0])]

# %%
df_test
# Out:
#         srch_id  prop_id
# 61281    270249    45457
# 213512   280456    62349
# 399846   292947    67320
# 368192   290835    18551
# 302772   286583   132475
# 551429   303050   102124
# 462483   297213    25628
# 923609   328257    30057
# 188439   278791    87674
# 376488   291420    59989
# 246731   282733   131445
# 197003   279358    25686
# 485794   298784    95397
# 655343   310096   139319
# 340436   288992    44912
# 988743   332575   123051
# 794789   319454    45364
# 629637   308388    26623
# 670471   311076    51131
# 703453   313303    24096
# 429453   294988   128571
# 104158   273101   118206
# 211850   280341    51211
# 400776   293004    52800
# 32090    268352    25909
# 620505   307751    95942
# 849492   323190    93646
# 570711   304390    28182
# 465823   297446   112113
# 782639   318653   102144
# ...         ...      ...
# 292844   285902   102897
# 533348   301911     8870
# 902149   326781    75781
# 26317    267969    80283
# 639103   309004    67545
# ...

# %%
df_test = df_test.sort_values('srch_id')

# %%
df_test.to_csv("ranking_list_baseline.csv", header=True, index=False)
