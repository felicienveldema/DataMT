# %%
import numpy as np
import pandas as pd

# %%
selected_columns = ['visitor_location_country_id','prop_country_id', 'prop_starrating', \
                    'prop_review_score', 'prop_location_score1', 'prop_location_score2', \
                    'prop_log_historical_price', 'position', 'price_usd','promotion_flag', \
                    'srch_query_affinity_score', 'random_bool', 'click_bool', 'booking_bool', \
                    'cr1','cr2']



# All attributes we want select
selected_columns = ['visitor_location_country_id','prop_country_id', 'prop_starrating', \
                    'prop_review_score', 'prop_location_score1', 'prop_location_score2', \
                    'prop_log_historical_price', 'price_usd','promotion_flag', \
                    'srch_query_affinity_score', 'random_bool']

# The attributes on which we are going to standardize on
# -> So for any datapoint x, we want to standardize x with respect to all datapoints with same
# 'visitor_location_country_id' AND 'prop_country_id' as x
standardize_on = ['visitor_location_country_id', 'prop_country_id']

# Of the selected attributes, the attributes which we standardize
columns_to_standardize = ['prop_starrating','price_usd', 'prop_review_score', \
                          'prop_location_score1', 'prop_location_score2', 'prop_log_historical_price']

# %%
# Read whole dataset
df = pd.read_csv('pcadf.csv', sep=',')

# %%
df.shape
# Out:
# (4958347, 33)

# %%
df_selection = df[selected_columns]

# %%
df_selection.median()
# Out:
# visitor_location_country_id    219.0000
# prop_country_id                219.0000
# prop_starrating                  3.0000
# prop_review_score                4.0000
# prop_location_score1             2.7700
# prop_location_score2             0.0690
# prop_log_historical_price        4.9100
# price_usd                      122.0000
# promotion_flag                   0.0000
# srch_query_affinity_score      -20.4513
# random_bool                      0.0000
# dtype: float64

# %%
df_selection.mean()
# Out:
# visitor_location_country_id    175.340453
# prop_country_id                173.973897
# prop_starrating                  3.180525
# prop_review_score                3.777777
# prop_location_score1             2.872589
# prop_location_score2             0.130385
# prop_log_historical_price        4.317913
# price_usd                      254.209590
# promotion_flag                   0.215620
# srch_query_affinity_score      -24.146418
# random_bool                      0.295900
# dtype: float64

# %%
df_selection = df_selection.fillna(df_selection.median())

# %%
# For each "key" ('visitor_location_country_id', 'prop_country_id'), we
# standardize a numeric attribute as a-> (a-m)/s, m=mean,s=std
# The dict "transf_param" remembers for each key encountered in whole training set the mean and std
# as tuple (m,s) where m,s both numpy arrays

transf_param = {}
k = 0
for name,group in df_selection[standardize_on+columns_to_standardize].groupby(by=standardize_on):
    mean = np.array(group[columns_to_standardize].mean())
    #print("mean is: " + str(mean))
    std = np.array(group[columns_to_standardize].std())
    #print("std is: " + str(std))

    if True in np.isnan(mean):# or True in np.isnan(std):
        print("mean" + str(name))
    
    if True in np.isnan(std):
        std = np.ones(len(columns_to_standardize))
        print("std " + str(name))
#        print(group)

    # If std gives 0, replace with 1
    epsilon = 0.01            # Reason is that we have found some cases where all values are 0.69, but std wasnt 0
    std[std<epsilon] = 1
    
    transf_param[name] = (mean,std)
    k=k+1
    if k % 18000 == 0:
        print(k)
        break
# Out:
# std (23, 165)
# std (36, 99)
# std (77, 119)
# std (79, 202)
# std (99, 208)
# std (103, 163)
# std (110, 165)
# std (214, 202)
# std (219, 208)

# %%
#print(len(df_selection['srch_destination_id'].unique()))
print(len(df_selection['visitor_location_country_id'].unique()))
print(len(df_selection['prop_country_id'].unique()))
# Out:
# 210
# 172

# %%
len(transf_param)
# Out:
# 4058

# %%
# Save the dict as file.
np.save('transf_param.npy', transf_param)

# %%
# After computing all means and std, and saved on file, we can normalize the test set.

# %%
# Load dict from file
saved_transf_param = np.load('transf_param.npy').item()

# %%
# Load whole test data
df_test = pd.read_csv('test_set_lines_500k.csv', sep=',')
#df_test = pd.read_csv('test_set_VU_DM_2014.csv', sep=',')

# %%
df_test.shape
# Out:
# (499999, 50)

# %%
df_test = df_test[selected_columns]

# %%
df_test.describe()
# Out:
#        visitor_location_country_id  prop_country_id  prop_starrating  \
# count                499999.000000    499999.000000    499999.000000
# mean                    175.334581       173.233276         3.184944
# std                      65.783272        68.669938         1.050451
# min                       1.000000         1.000000         0.000000
# 25%                     100.000000       100.000000         3.000000
# 50%                     219.000000       219.000000         3.000000
# 75%                     219.000000       219.000000         4.000000
# max                     230.000000       230.000000         5.000000
#
#        prop_review_score  prop_location_score1  prop_location_score2  \
# count      499245.000000         499999.000000         392126.000000
# mean            3.780674              2.881491              0.130132
# std             1.044247              1.533979              0.160393
# min             0.000000              0.000000              0.000000
# 25%             3.500000              1.790000              0.018400
# 50%             4.000000              2.830000              0.068000
# 75%             4.500000              4.060000              0.179900
# max             5.000000              6.980000              0.999600
#
#        prop_log_historical_price     price_usd  promotion_flag  \
# count              499999.000000  4.999990e+05   499999.000000
# mean                    4.327942  2.928037e+02        0.219198
# std                     1.829020  2.520525e+04        0.413704
# min                     0.000000  8.000000e-02        0.000000
# 25%                     4.450000  8.500000e+01        0.000000
# 50%                     4.920000  1.230000e+02        0.000000
# 75%                     5.320000  1.856900e+02        0.000000
# max                     6.210000  9.661340e+06        1.000000
#
#        srch_query_affinity_score    random_bool
# count               31395.000000  499999.000000
# mean                  -24.614399       0.297205
# std                    16.774284       0.457028
# min                  -241.027700       0.000000
# 25%                   -30.893400       0.000000
# 50%                   -20.507000       0.000000
# 75%                   -13.767900       1.000000
# max                    -3.155400       1.000000

# %%
df_test.count()
# Out:
# visitor_location_country_id    499999
# prop_country_id                499999
# prop_starrating                499999
# prop_review_score              499245
# prop_location_score1           499999
# prop_location_score2           392126
# prop_log_historical_price      499999
# price_usd                      499999
# promotion_flag                 499999
# srch_query_affinity_score       31395
# random_bool                    499999
# dtype: int64

# %%
# Have to fill in missing values too...
df_test = df_test.fillna(df_selection.median())

# %%
df_test.count()
# Out:
# visitor_location_country_id    499999
# prop_country_id                499999
# prop_starrating                499999
# prop_review_score              499999
# prop_location_score1           499999
# prop_location_score2           499999
# prop_log_historical_price      499999
# price_usd                      499999
# promotion_flag                 499999
# srch_query_affinity_score      499999
# random_bool                    499999
# dtype: int64

# %%
#print(len(df_test['srch_destination_id'].unique()))
print(len(df_test['visitor_location_country_id'].unique()))
print(len(df_test['prop_country_id'].unique()))
# Out:
# 143
# 142

# %%
df_selection[(df_selection['visitor_location_country_id'] == 2) & (df_selection['prop_country_id'] == 32)].std()
# Out:
# visitor_location_country_id     0.000000
# prop_country_id                 0.000000
# prop_starrating                 0.480384
# prop_review_score               1.244217
# prop_location_score1            1.685590
# prop_location_score2            0.072103
# prop_log_historical_price       0.000000
# price_usd                      77.783724
# promotion_flag                  0.518875
# srch_query_affinity_score       0.000000
# random_bool                     0.000000
# dtype: float64

# %%
num_attr_to_stand = len(columns_to_standardize)
avg_mean = np.zeros(num_attr_to_stand)
avg_std = np.zeros(num_attr_to_stand)

for key,value in saved_transf_param.items():

    avg_mean = avg_mean + value[0]
    avg_std = avg_std + value[1]

avg_mean = avg_mean / len(saved_transf_param)
avg_std = avg_std / len(saved_transf_param)
print(avg_mean)
print(avg_std)
# Out:
# [3.61359367e+00 4.29132391e+02 3.44736381e+00 3.04779461e+00
#  1.17998774e-01 4.40103201e+00]
# [8.97319190e-01 1.08478456e+03 1.27501350e+00 1.09386185e+00
#  1.20702599e-01 1.08035115e+00]

# %%
# In the test set, we go through each ('visitor_location_country_id', 'prop_country_id') group
# and standardize the values of (some of ) the attributes

# Remember howmany groups in total, and howmany of them were not encountered before
num_data_points = 0
num_data_points_unknown = 0
num_unknowns = 0
k = 0
for name,group in df_test.groupby(by=standardize_on):
    if k % 6000 == 0:
        print(k)
    k = k+1
    num_data_points = num_data_points + group.shape[0]
    
    if name in saved_transf_param:
        # Means we have encountered the key in training set
        cur_params = saved_transf_param[name]
#        print(cur_params)
    else:
        # Means we havent encountered the key in training set
        print("Unknown group " + str(k) + ", with key: " + str(name))
        num_unknowns = num_unknowns + 1
        num_data_points_unknown = num_data_points_unknown + group.shape[0]
        # For unknown key, we have use:
        #  - mean = avg mean of all known keys
        #  - std = avg std of all known keys
        cur_params = (avg_mean*np.ones(num_attr_to_stand),avg_std*np.ones(num_attr_to_stand))

#    print(df_test.loc[(df_test['visitor_location_country_id'] == name[0]) & (df_test['srch_destination_id'] == name[1])])
    df_test.loc[(df_test['visitor_location_country_id'] == name[0]) & (df_test['prop_country_id'] == name[1]), \
                columns_to_standardize] = \
            (df_test.loc[(df_test['visitor_location_country_id'] == name[0]) & \
                        (df_test['prop_country_id'] == name[1]), columns_to_standardize] - cur_params[0]) / cur_params[1]
#    print(df_test.loc[(df_test['visitor_location_country_id'] == name[0]) & (df_test['srch_destination_id'] == name[1])])

print("total num of unknowns is: " + str(num_unknowns))
print("total num groups is: " + str(k))
print("total num of unknown data points is: " + str(num_data_points_unknown))
print("total num of data points is: " + str(num_data_points))
# Out:
# 0
# Unknown group 3, with key: (2, 56)
# Unknown group 7, with key: (2, 221)
# Unknown group 8, with key: (3, 48)
# Unknown group 24, with key: (5, 48)
# Unknown group 28, with key: (5, 220)
# Unknown group 37, with key: (10, 202)
# Unknown group 38, with key: (11, 127)
# Unknown group 56, with key: (13, 163)
# Unknown group 66, with key: (14, 158)
# Unknown group 69, with key: (14, 211)
# Unknown group 73, with key: (15, 26)
# Unknown group 77, with key: (15, 48)
# Unknown group 90, with key: (16, 32)
# Unknown group 92, with key: (16, 129)
# Unknown group 95, with key: (18, 9)
# Unknown group 100, with key: (22, 18)
# Unknown group 102, with key: (22, 68)
# Unknown group 105, with key: (23, 4)
# Unknown group 118, with key: (23, 201)
# Unknown group 122, with key: (23, 217)
# Unknown group 125, with key: (26, 4)
# Unknown group 131, with key: (28, 50)
# Unknown group 134, with key: (30, 192)
# Unknown group 157, with key: (31, 83)
# Unknown group 191, with key: (32, 63)
# Unknown group 201, with key: (32, 222)
# Unknown group 214, with key: (33, 145)
# Unknown group 216, with key: (33, 181)
# Unknown group 218, with key: (33, 216)
# Unknown group 227, with key: (36, 194)
# Unknown group 235, with key: (39, 73)
# Unknown group 242, with key: (39, 132)
# Unknown group 264, with key: (44, 11)
# Unknown group 265, with key: (45, 31)
# Unknown group 269, with key: (47, 39)
# Unknown group 271, with key: (47, 92)
# Unknown group 272, with key: (47, 182)
# Unknown group 273, with key: (47, 202)
# Unknown group 299, with key: (53, 103)
# Unknown group 360, with key: (55, 192)
# Unknown group 380, with key: (56, 74)
# Unknown group 388, with key: (56, 207)
# Unknown group 392, with key: (56, 224)
# Unknown group 393, with key: (57, 31)
# Unknown group 395, with key: (57, 99)
# Unknown group 398, with key: (59, 13)
# Unknown group 406, with key: (59, 90)
# Unknown group 412, with key: (59, 181)
# Unknown group 423, with key: (60, 223)
# Unknown group 436, with key: (68, 138)
# Unknown group 447, with key: (71, 99)
# Unknown group 449, with key: (73, 25)
# Unknown group 455, with key: (73, 100)
# Unknown group 458, with key: (73, 137)
# Unknown group 477, with key: (80, 9)
# Unknown group 478, with key: (80, 17)
# Unknown group 481, with key: (80, 70)
# Unknown group 484, with key: (80, 195)
# Unknown group 499, with key: (82, 47)
# Unknown group 500, with key: (83, 31)
# Unknown group 511, with key: (86, 219)
# Unknown group 514, with key: (89, 55)
# Unknown group 525, with key: (92, 18)
# Unknown group 592, with key: (99, 108)
# Unknown group 597, with key: (99, 131)
# Unknown group 600, with key: (99, 146)
# Unknown group 618, with key: (100, 16)
# Unknown group 635, with key: (100, 57)
# Unknown group 640, with key: (100, 72)
# Unknown group 669, with key: (100, 161)
# Unknown group 672, with key: (100, 179)
# Unknown group 690, with key: (102, 42)
# Unknown group 707, with key: (103, 157)
# Unknown group 712, with key: (103, 213)
# Unknown group 718, with key: (109, 23)
# Unknown group 719, with key: (109, 56)
# Unknown group 723, with key: (112, 55)
# Unknown group 724, with key: (113, 32)
# Unknown group 725, with key: (115, 99)
# Unknown group 733, with key: (117, 86)
# Unknown group 749, with key: (122, 103)
# Unknown group 750, with key: (123, 18)
# Unknown group 756, with key: (125, 32)
# Unknown group 761, with key: (125, 181)
# Unknown group 766, with key: (127, 205)
# Unknown group 772, with key: (129, 17)
# Unknown group 784, with key: (129, 48)
# Unknown group 826, with key: (130, 73)
# Unknown group 828, with key: (130, 117)
# Unknown group 843, with key: (132, 92)
# Unknown group 859, with key: (132, 201)
# Unknown group 866, with key: (132, 224)
# Unknown group 867, with key: (134, 123)
# Unknown group 868, with key: (137, 4)
# Unknown group 871, with key: (137, 50)
# Unknown group 884, with key: (137, 220)
# Unknown group 895, with key: (139, 31)
# Unknown group 896, with key: (142, 127)
# Unknown group 900, with key: (146, 129)
# Unknown group 901, with key: (148, 60)
# Unknown group 902, with key: (149, 35)
# Unknown group 905, with key: (149, 158)
# Unknown group 907, with key: (152, 47)
# Unknown group 917, with key: (154, 220)
# Unknown group 923, with key: (155, 186)
# Unknown group 924, with key: (155, 214)
# Unknown group 925, with key: (157, 103)
# Unknown group 926, with key: (158, 1)
# Unknown group 936, with key: (158, 65)
# Unknown group 937, with key: (158, 68)
# Unknown group 944, with key: (158, 112)
# Unknown group 951, with key: (158, 163)
# Unknown group 959, with key: (160, 81)
# Unknown group 961, with key: (160, 100)
# Unknown group 965, with key: (163, 99)
# Unknown group 971, with key: (167, 132)
# Unknown group 973, with key: (172, 102)
# Unknown group 978, with key: (177, 50)
# Unknown group 1008, with key: (182, 154)
# Unknown group 1016, with key: (188, 99)
# Unknown group 1026, with key: (202, 10)
# Unknown group 1036, with key: (203, 215)
# Unknown group 1037, with key: (203, 229)
# Unknown group 1061, with key: (206, 187)
# Unknown group 1065, with key: (208, 22)
# Unknown group 1067, with key: (211, 225)
# Unknown group 1070, with key: (212, 15)
# Unknown group 1088, with key: (213, 158)
# Unknown group 1089, with key: (213, 163)
# Unknown group 1093, with key: (214, 60)
# Unknown group 1107, with key: (215, 68)
# Unknown group 1125, with key: (216, 18)
# Unknown group 1130, with key: (216, 37)
# Unknown group 1190, with key: (219, 25)
# Unknown group 1274, with key: (219, 222)
# Unknown group 1319, with key: (220, 200)
# Unknown group 1330, with key: (221, 99)
# total num of unknowns is: 137
# total num groups is: 1336
# total num of unknown data points is: 3227
# total num of data points is: 499999

# %%
df_test.describe()
# Out:
#        visitor_location_country_id  prop_country_id  prop_starrating  \
# count                499999.000000    499999.000000    499999.000000
# mean                    175.334581       173.233276        -0.001527
# std                      65.783272        68.669938         1.007711
# min                       1.000000         1.000000       -10.206207
# 25%                     100.000000       100.000000        -0.710445
# 50%                     219.000000       219.000000         0.064770
# 75%                     219.000000       219.000000         0.765414
# max                     230.000000       230.000000         3.171904
#
#        prop_review_score  prop_location_score1  prop_location_score2  \
# count      499999.000000         499999.000000         499999.000000
# mean           -0.002882              0.004015              0.009114
# std             1.013278              1.109021              1.084909
# min           -16.782928            -60.074071             -4.792055
# 25%            -0.451397             -0.680050             -0.635620
# 50%             0.151539              0.039591             -0.306247
# 75%             0.754064              0.756748              0.172508
# max             3.227486             50.133618             48.308228
#
#        prop_log_historical_price     price_usd  promotion_flag  \
# count              499999.000000  4.999990e+05   499999.000000
# mean                   -0.020173  9.371014e+01        0.219198
# std                     1.190061  2.497270e+04        0.413704
# min                   -30.664914 -3.160000e+02        0.000000
# 25%                     0.069328 -7.945599e-02        0.000000
# 50%                     0.330861 -3.081505e-02        0.000000
# 75%                     0.548485  1.438829e-02        0.000000
# max                     6.210000  9.661340e+06        1.000000
#
#        srch_query_affinity_score    random_bool
# count              499999.000000  499999.000000
# mean                  -20.712702       0.297205
# std                     4.322853       0.457028
# min                  -241.027700       0.000000
# 25%                   -20.451300       0.000000
# 50%                   -20.451300       0.000000
# 75%                   -20.451300       1.000000
# max                    -3.155400       1.000000

# %%
df_test.count()
# Out:
# visitor_location_country_id    499999
# prop_country_id                499999
# prop_starrating                499999
# prop_review_score              499999
# prop_location_score1           499999
# prop_location_score2           499999
# prop_log_historical_price      499999
# price_usd                      499999
# promotion_flag                 499999
# srch_query_affinity_score      499999
# random_bool                    499999
# dtype: int64

# %%
df_test[df_test['price_usd'] > 1000]
# Out:
#         visitor_location_country_id  prop_country_id  prop_starrating  \
# 489415                          202              100         1.450706
# 489416                          202              100         1.450706
# 489417                          202              100         0.267235
# 489418                          202              100         2.634176
# 489419                          202              100         0.267235
# 489420                          202              100         0.267235
# 489421                          202              100         1.450706
# 489422                          202              100         2.634176
#
#         prop_review_score  prop_location_score1  prop_location_score2  \
# 489415           1.239309              6.197749              0.179605
# 489416           0.765005              6.180059              0.179605
# 489417           0.290702              6.180059              0.179605
# 489418           0.765005              6.126989             41.381062
# 489419           0.765005              6.126989             40.299786
# 489420           0.290702              5.702431              2.907003
# 489421           0.765005              6.180059              0.179605
# 489422           0.765005              6.126989             47.271595
#
#         prop_log_historical_price     price_usd  promotion_flag  \
# 489415                   4.073617  7.719411e+06               0
# 489416                   2.561759  7.043117e+06               0
# 489417                   1.469862  3.276644e+06               1
# 489418                   4.703558  9.661340e+06               0
# 489419                   1.931818  3.076364e+06               0
# 489420                   2.729743  4.279672e+06               1
# 489421                   3.149704  6.753277e+06               0
# 489422                   4.073617  5.016168e+06               1
#
#         srch_query_affinity_score  random_bool
# 489415                   -20.4513            0
# 489416                   -20.4513            0
# 489417                   -20.4513            0
# 489418                   -20.4513            0
# 489419                   -20.4513            0
# 489420                   -20.4513            0
# 489421                   -20.4513            0
# 489422                   -20.4513            0

# %%
saved_transf_param[(202,100)]
#saved_transf_param[(219,100)]
# Out:
# (array([2.77419355, 0.0116129 , 3.69354839, 1.14645161, 0.06677419,
#         4.82      ]),
#  array([0.84497248, 1.        , 1.05417756, 0.56529372, 0.01239277,
#         0.23811762]))

# %%
(df_test[(df_test['visitor_location_country_id'] == 202) & \
             (df_test['prop_country_id'] == 100)][columns_to_standardize] )#- saved_transf_param[(202,100)][0])\
#/saved_transf_param[(202,100)][1]
# Out:
#         prop_starrating     price_usd  prop_review_score  \
# 489415         1.450706  7.719411e+06           1.239309
# 489416         1.450706  7.043117e+06           0.765005
# 489417         0.267235  3.276644e+06           0.290702
# 489418         2.634176  9.661340e+06           0.765005
# 489419         0.267235  3.076364e+06           0.765005
# 489420         0.267235  4.279672e+06           0.290702
# 489421         1.450706  6.753277e+06           0.765005
# 489422         2.634176  5.016168e+06           0.765005
#
#         prop_location_score1  prop_location_score2  prop_log_historical_price
# 489415              6.197749              0.179605                   4.073617
# 489416              6.180059              0.179605                   2.561759
# 489417              6.180059              0.179605                   1.469862
# 489418              6.126989             41.381062                   4.703558
# 489419              6.126989             40.299786                   1.931818
# 489420              5.702431              2.907003                   2.729743
# 489421              6.180059              0.179605                   3.149704
# 489422              6.126989             47.271595                   4.073617

# %%
df_selection[(df_selection['visitor_location_country_id'] == 219) & \
             (df_selection['prop_country_id'] == 100) & \
             (df_selection['price_usd']>10000)]
# Out:
#          visitor_location_country_id  prop_country_id  prop_starrating  \
# 4115920                          219              100                2
# 4115921                          219              100                4
# 4115923                          219              100                3
# 4115924                          219              100                2
# 4115925                          219              100                4
# 4115927                          219              100                3
# 4115928                          219              100                2
#
#          prop_review_score  prop_location_score1  prop_location_score2  \
# 4115920                4.0                  0.69                0.0022
# 4115921                4.0                  4.19                0.0275
# 4115923                4.5                  4.51                0.0972
# 4115924                3.5                  1.79                0.0121
# 4115925                3.5                  2.08                0.0132
# 4115927                4.5                  4.49                0.0498
# 4115928                4.0                  1.39                0.0058
#
#          prop_log_historical_price  price_usd  promotion_flag  \
# 4115920                       4.77   10736.90               0
# 4115921                       5.28   15248.24               0
# 4115923                       5.38   17593.82               1
# 4115924                       4.72   18252.54               1
# 4115925                       4.95   16564.70               1
# 4115927                       5.33   19458.56               0
# 4115928                       4.70   12991.59               1
#
#          srch_query_affinity_score  random_bool
# 4115920                   -20.4513            0
# 4115921                   -20.4513            0
# 4115923                   -20.4513            0
# 4115924                   -20.4513            0
# 4115925                   -20.4513            0
# 4115927                   -20.4513            0
# 4115928                   -20.4513            0

# %%
# Save standardized attributres to file
df_test.to_csv('test_stand.csv')
